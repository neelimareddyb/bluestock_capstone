# %% [markdown]
# # Exploratory Data Analysis (EDA) — Mutual Fund Analytical Framework
# ### Day 3 Capstone Analytics Verification Ledger
#
# This notebook contains the complete transactional, scale vector, and structural layout evaluation mapping over 15 charts.

# %%
import os
plot_files = sorted(os.listdir('data/processed/plots'))
print(f'Total production charts exported successfully: {len(plot_files)}')
for f in plot_files: print(' -> ', f)

# %% [markdown]
# ---
# ## 🔬 Official 10 Key Corporate EDA Findings
#
# ### Insight 1
# **Observation:** Daily asset tracking shows exponential wealth multiplication patterns during the 2023 Bull Run across all 40 structural schemes, which were later balanced by systematic drawdowns during the 2024 market correction phase.
# *Source Asset:* Refer to chart1_nav_trends.png
#
# ### Insight 2
# **Observation:** SBI Mutual Fund shows clear historical scale dominance within the Indian macro asset space, peaking at a massive scale asset footprint of ₹12.5 Lakh Crores by the close of the fiscal year 2025.
# *Source Asset:* Refer to chart2_aum_bars.png
#
# ### Insight 3
# **Observation:** Systematic Investment Plan retail capital inflow velocity achieved a critical historic all-time high milestone of ₹31,002 Crores in December 2025.
# *Source Asset:* Refer to chart3_sip_time_series.png
#
# ### Insight 4
# **Observation:** Heatmap concentration matrices reveal that thematic and small-cap assets absorbed massive capital inflows compared to defensive standard cash-equivalent debt instruments during late 2024 and 2025.
# *Source Asset:* Refer to chart4_category_heatmap.png
#
# ### Insight 5
# **Observation:** The core engine of Indian retail investment activity belongs to young professionals, with the 26-35 age bracket making up a dominant 41.1% of the overall user portfolio distribution.
# *Source Asset:* Refer to chart5_age_demographics_pie.png
#
# ### Insight 6
# **Observation:** Order volume ticket sizes follow a tight log-normal distribution with highly uniform median buy-in metrics across all working-age brackets.
# *Source Asset:* Refer to chart6_ticket_size_boxplot.png
#
# ### Insight 7
# **Observation:** Gender registry distributions present an asymmetric capital engagement balance, with male investment channels holding a 62.0% market share footprint compared to female investor accounts.
# *Source Asset:* Refer to chart7_gender_donut.png
#
# ### Insight 8
# **Observation:** State-level geographic concentration is highly localized within top economic hubs, with Maharashtra leading all inbound retail capital generation channels.
# *Source Asset:* Refer to chart8_geographic_states.png
#
# ### Insight 9
# **Observation:** Top 30 economic urban centers continue to capture the vast majority of capital deployment channels at 72.4%, though B30 regional districts represent a steady 27.6% growth vector.
# *Source Asset:* Refer to chart9_tier_market_share.png
#
# ### Insight 10
# **Observation:** National investor participation channels scaled phenomenally over the 48-month evaluation window, doubling active system folio accounts from 13.26 Crores to 26.12 Crores.
# *Source Asset:* Refer to chart10_folio_growth.png
